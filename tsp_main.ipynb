# %%
! git clone https://github.com/SperanzaTY/TSP-Funsearch.git
! pip install torch
# Out:
# fatal: destination path 'TSP-Funsearch' already exists and is not an empty directory.
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.11/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.11/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
import sys

sys.path.append('/content/TSP1/')

# %%
# %cd ./TSP-Funsearch/
sys.path.append('/home/jovyan/TSP-Funsearch')
# Out:
# /home/jovyan/TSP-Funsearch

# %%
import matplotlib.pyplot as plt
import sys, os

dataset = {}
def prepare_dataset(filename):
  # print(type(filename))
  with open(filename, "r") as f:
      lines = f.readlines()

  # 解析节点坐标数据
  node_coords = {}
  found_node_section = False
  for line in lines:
      if found_node_section:
          if line.strip() == "EOF":
              break
          node_id, x, y = map(float, line.strip().split()) if filename == 'ali535.tsp' else map(int, line.strip().split())
          node_coords[node_id] = (x, y)
      elif line.startswith("NODE_COORD_SECTION"):
          found_node_section = True

  # 绘制节点图
  plt.figure(figsize=(8, 6))
  for node_id, (x, y) in node_coords.items():
      plt.plot(x, y, 'bo')
      plt.text(x, y, str(node_id), fontsize=8, ha='right')
  plt.title('TSP Node Map')
  plt.xlabel('X Coordinate')
  plt.ylabel('Y Coordinate')
  plt.grid(True)
  plt.show()
  dataset[filename] = node_coords
  # print(node_coords)

filepath = ['./tsp1/a280.tsp','./tsp1/att532.tsp','./tsp1/att48.tsp']
# filepath = ['./tsp1/a280.tsp']
for i in filepath:
  # print(i)
  prepare_dataset(i)

# %%
import numpy as np
def coordinates_to_distance_matrix(coordinates):
    num_cities = len(coordinates)
    # 创建一个空的距离矩阵
    distance_matrix = np.zeros((num_cities, num_cities))
    # 获取城市的列表，并确保顺序一致
    city_ids = sorted(coordinates.keys())
    
    # 计算每对城市之间的欧式距离
    for i in range(num_cities):
        for j in range(i + 1, num_cities):
            coord1 = coordinates[city_ids[i]]
            coord2 = coordinates[city_ids[j]]
            # 计算两点之间的欧式距离
            distance = np.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2)
            distance_matrix[i][j] = distance_matrix[j][i] = distance
    
    return distance_matrix
# print(dataset)

input = {}
for i in dataset.keys():
    distance_matrix = coordinates_to_distance_matrix(dataset[i])
    input[i] = distance_matrix
print(input.keys())
# Out:
# dict_keys(['./tsp1/a280.tsp', './tsp1/att532.tsp', './tsp1/att48.tsp'])

# %%
import time
import json
import multiprocessing
from typing import Collection, Any
import http.client
from implementation import sampler


def _trim_preface_of_body(sample: str) -> str:
    """Trim the redundant descriptions/symbols/'def' declaration before the function body.
    Please see my comments in sampler.LLM (in sampler.py).
    Since the LLM used in this file is not a pure code completion LLM, this trim function is required.

    -Example sample (function & description generated by LLM):
    -------------------------------------
    This is the optimized function ...
    def priority_v2(...) -> ...:
        return ...
    This function aims to ...
    -------------------------------------
    -This function removes the description above the function's signature, and the function's signature.
    -The indent of the code is preserved.
    -Return of this function:
    -------------------------------------
        return ...
    This function aims to ...
    -------------------------------------
    """
    lines = sample.splitlines()
    func_body_lineno = 0
    find_def_declaration = False
    for lineno, line in enumerate(lines):
        # find the first 'def' statement in the given code
        if line[:3] == 'def':
            func_body_lineno = lineno
            find_def_declaration = True
            break
    if find_def_declaration:
        code = ''
        for line in lines[func_body_lineno + 1:]:
            code += line + '\n'
        return code
    return sample


class LLMAPI(sampler.LLM):
    """Language model that predicts continuation of provided source code.
    """

    def __init__(self, samples_per_prompt: int, trim=True):
        super().__init__(samples_per_prompt)
        additional_prompt = ('Complete a different and more complex Python function. '
                             'Be creative and you can insert multiple if-else and for-loop in the code logic.'
                             'Only output the Python code, no descriptions.')
        self._additional_prompt = additional_prompt
        self._trim = trim

    def draw_samples(self, prompt: str) -> Collection[str]:
        """Returns multiple predicted continuations of `prompt`."""
        return [self._draw_sample(prompt) for _ in range(self._samples_per_prompt)]

    def _draw_sample(self, content: str) -> str:
        prompt = '\n'.join([content, self._additional_prompt])
        while True:
            try:
                conn = http.client.HTTPSConnection("api.chatanywhere.com.cn")
                payload = json.dumps({
                    "max_tokens": 512,
                    "model": "gpt-3.5-turbo",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                })
                headers = {
                    'Authorization': 'Bearer sk-y8d7GwsGxwaTmOYWoDIRisEB6TvU91KwDS8LMdgayE6CqazP',
                    'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
                    'Content-Type': 'application/json'
                }
                conn.request("POST", "/v1/chat/completions", payload, headers)
                res = conn.getresponse()
                data = res.read().decode("utf-8")
                data = json.loads(data)
                response = data['choices'][0]['message']['content']
                # trim function
                if self._trim:
                    response = _trim_preface_of_body(response)
                return response
            except Exception:
                time.sleep(2)
                continue

# %%
from implementation import evaluator
from implementation import evaluator_accelerate

# Define a class Sandbox, which is responsible for safely executing generated code.
class Sandbox(evaluator.Sandbox):
    """Sandbox for executing generated code. 

    Sandbox returns the 'score' of the program and:
    1) avoids the generated code to be harmful (accessing the internet, take up too much RAM).
    2) stops the execution of the code in time (avoid endless loop).
    """

    def __init__(self, verbose=False, numba_accelerate=True):
        """
        Args:
            verbose         : Print evaluate information.
            numba_accelerate: Use numba to accelerate the evaluation. It should be noted that not all numpy functions
                              support numba acceleration, such as np.piecewise().
        """
        self._verbose = verbose
        self._numba_accelerate = numba_accelerate

    def run(
            self,
            program: str,
            function_to_run: str,  # refers to the name of the function to run (e.g., 'evaluate')
            function_to_evolve: str,  # accelerate the code by decorating @numba.jit() on function_to_evolve.
            inputs: Any,  # refers to the dataset
            test_input: str,  # refers to the current instance
            timeout_seconds: int, # The time limit for execution.
            **kwargs  # Additional run-time arguments if needed.
    ) -> tuple[Any, bool]:
        """Returns `function_to_run(test_input)` and whether execution succeeded.

        If the generated code (generated by LLM) is executed successfully,
        the output of this function is the score of a given program.
        this SandBox is only designed for bin-packing problem.
        """

        # Setup the execution environment and parameters.
        dataset = inputs[test_input]
        try:
            result_queue = multiprocessing.Queue()
            process = multiprocessing.Process(
                target=self._compile_and_run_function,
                args=(program, function_to_run, function_to_evolve, dataset, self._numba_accelerate, result_queue)
            )

            # Start the process and monitor for the timeout.
            process.start()
            process.join(timeout=timeout_seconds)
            if process.is_alive():
                # if the process is not finished in time, we consider the program illegal
                process.terminate()
                process.join()
                results = None, False
            else:
                # Collect the results if available.
                if not result_queue.empty():
                    results = result_queue.get_nowait()
                else:
                    results = None, False

            return results
        except:
            # Handle exceptions and indicate failure.
            return None, False

    def _compile_and_run_function(self, program, function_to_run, function_to_evolve, dataset, numba_accelerate,
                                  result_queue):
        try:
            # optimize the code (decorate function_to_run with @numba.jit())
            if numba_accelerate:
                program = evaluator_accelerate.add_numba_decorator(
                    program=program,
                    function_to_evolve=function_to_evolve
                )
            # compile the program, execute it in the sandbox's global namespace, and maps the global func/var/class name to its address
            all_globals_namespace = {}
            # execute the program, map func/var/class to global namespace
            exec(program, all_globals_namespace)
            # get the pointer of 'function_to_run'
            function_to_run = all_globals_namespace[function_to_run]
            # return the execution results
            results = function_to_run(dataset)
            # the results must be int or float
            # Check if the results are of expected types (int or float).
            if not isinstance(results, (int, float)):
                result_queue.put((None, False))
                return
            result_queue.put((results, True))
        except Exception:
            # if raise any exception, we assume the execution failed
            result_queue.put((None, False))

# %%
import numpy as np

def heuristic_tsp_solver(distances):
    """Solve the TSP using a simple heuristic that selects the nearest unvisited city."""
    num_cities = len(distances)
    visited = [False] * num_cities
    current_city = 0
    visited[current_city] = True
    tour = [current_city]
    total_distance = 0

    while len(tour) < num_cities:
        next_city = None
        min_distance = float('inf')
        for city in range(num_cities):
            if not visited[city] and distances[current_city][city] < min_distance:
                next_city = city
                min_distance = distances[current_city][city]
        visited[next_city] = True
        tour.append(next_city)
        total_distance += min_distance
        current_city = next_city

    # Close the loop by returning to the starting city
    total_distance += distances[current_city][tour[0]]
    tour.append(tour[0])  # Optionally return to the starting city for visualization
    return tour, total_distance

# @funsearch.run
def evaluate(distance_matrix):
    """Evaluate heuristic function on a provided distance matrix for the TSP."""
    tour, total_distance = heuristic_tsp_solver(distance_matrix)
    # return {'tour': tour, 'total_distance': total_distance}
    return -total_distance

# @funsearch.evolve
def priority(current_city, distances):
    """Determine priority for each city to visit from the current city based on distance."""
    num_cities = len(distances)
    priorities = np.full(num_cities, np.inf)
    for city in range(num_cities):
        if distances[current_city][city] > 0:  # Assume 0 means not connected or same city
            # Inverse of distance as priority: closer cities have higher priority
            priorities[city] = -distances[current_city][city]
    return priorities

# print(dataset['./tsp1/a280.tsp'])
path = evaluate(distance_matrix)
print(path)
# print(greedy_tsp_solver
# Out:
# -40526.42105630375

# %%
specification = r'''
import numpy as np

def heuristic_tsp_solver(distances, priority_func):
    """Solve the TSP by selecting the next city based on a complex priority function."""
    num_cities = len(distances)
    visited = [False] * num_cities
    current_city = 0
    visited[current_city] = True
    tour = [current_city]
    total_distance = 0

    while len(tour) < num_cities:
        # Get complex priorities for the next city based on the current city
        priorities = priority_func(current_city, distances, visited)
        # Mask priorities for visited cities to ensure they are not selected
        masked_priorities = np.where(visited, np.inf, priorities)
        # Select the next city with the highest priority (lowest cost)
        next_city = np.argmin(masked_priorities)
        visited[next_city] = True
        tour.append(next_city)
        total_distance += distances[current_city][next_city]
        current_city = next_city

    # Close the loop by returning to the starting city
    total_distance += distances[current_city][tour[0]]
    tour.append(tour[0])  # Optionally return to the starting city for visualization
    return tour, total_distance

@funsearch.run
def evaluate(distance_matrix):
    """Evaluate heuristic function on a provided distance matrix for the TSP."""
    tour, total_distance = heuristic_tsp_solver(distance_matrix, priority)
    # return {'tour': tour, 'total_distance': total_distance}
    return -total_distance

@funsearch.evolve
def priority(current_city, distances, visited):
    """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
    num_cities = len(distances)
    priorities = np.full(num_cities, np.inf)
    for city in range(num_cities):
        if not visited[city]:
            # Inverse of the distance (closer cities have higher priority)
            distance_priority = -distances[current_city][city]
            # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
            dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
            priorities[city] = distance_priority * dynamic_cost
    return priorities

'''

# %%
from implementation import funsearch
from implementation import config

# It should be noted that the if __name__ == '__main__' is required.
# Because the inner code uses multiprocess evaluation.
if __name__ == '__main__':
    class_config = config.ClassConfig(llm_class=LLMAPI, sandbox_class=Sandbox)
    config = config.Config(samples_per_prompt=1, evaluate_timeout_seconds=30)
    global_max_sample_num = 80  # if it is set to None, funsearch will execute an endless loop
    # print(dataset,config,class_config)
    funsearch.main(
        specification=specification,
        inputs=input,
        config=config,
        max_sample_nums=global_max_sample_num,
        class_config=class_config,
        log_dir='../logs/funsearch_llm_api'
    )
# Out:
# 2024-04-20 13:21:24.832455: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-20 13:21:24.832504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-20 13:21:24.833964: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-20 13:21:24.841261: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-20 13:21:25.756890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:absl:Best score of island 0 increased to -838152.186534627
# INFO:absl:Best score of island 1 increased to -838152.186534627
# INFO:absl:Best score of island 2 increased to -838152.186534627
# INFO:absl:Best score of island 3 increased to -838152.186534627
# INFO:absl:Best score of island 4 increased to -838152.186534627
# INFO:absl:Best score of island 5 increased to -838152.186534627
# INFO:absl:Best score of island 6 increased to -838152.186534627
# INFO:absl:Best score of island 7 increased to -838152.186534627
# INFO:absl:Best score of island 8 increased to -838152.186534627
# INFO:absl:Best score of island 9 increased to -838152.186534627
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             # Inverse of the distance (closer cities have higher priority)
#             distance_priority = -distances[current_city][city]
#             # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
#             priorities[city] = distance_priority * dynamic_cost
#     return priorities
# ------------------------------------------------------
# Score        : -838152.186534627
# Sample time  : None
# Evaluate time: 3.3935673236846924
# Sample orders: None
# ======================================================
# INFO:absl:Best score of island 4 increased to 0.0
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             num_neighbors = np.count_nonzero(distances[city])
#             if num_neighbors == 0:  # If the city has no neighbors, prioritize it less
#                 distance_priority *= 0.5
#             else:
#                 for neighbor in range(num_cities):
#                     if distances[city][neighbor] != 0:
#                         priorities[city] += distances[city][neighbor] / num_neighbors
#
#             if city % 2 == 0:  # If the city index is even, increase its priority
#                 priorities[city] *= 1.2
#
#     return priorities
# ------------------------------------------------------
# Score        : 0.0
# Sample time  : 25.433746814727783
# Evaluate time: 4.87352991104126
# Sample orders: 2
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v0`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     max_distance = np.max(distances)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             # Inverse of the distance (closer cities have higher priority)
#             distance_priority = -distances[current_city][city]
#
#             # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
#
#             # Check if the city is the farthest from current city
#             if distances[current_city][city] == max_distance:
#                 distance_priority += 100
#
#             # Check if the city is the closest to a particular city
#             if city == 0:
#                 distance_priority += 50
#
#             # Check if the city has been visited multiple times
#             if np.count_nonzero(visited) > 3:
#                 distance_priority += 25
#
#             priorities[city] = distance_priority * dynamic_cost
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 35.50910544395447
# Evaluate time: 3.6435630321502686
# Sample orders: 3
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             num_neighbors = np.count_nonzero(distances[city])
#             if num_neighbors == 0:
#                 distance_priority *= 0.5
#             else:
#                 for neighbor in range(num_cities):
#                     if distances[city][neighbor] != 0:
#                         priorities[city] += distances[city][neighbor] / num_neighbors
#
#             if city % 2 == 0:
#                 priorities[city] *= 1.2
#
#             if distances[current_city][city] > np.mean(distances[current_city]) and distances[current_city][city] > np.mean(distances[:, city]):
#                 priorities[city] += 1
#
#             if city == np.argmax(distances[current_city]):
#                 priorities[city] += 5
#
#     return priorities
# ------------------------------------------------------
# Score        : 0.0
# Sample time  : 17.165810108184814
# Evaluate time: 6.452099561691284
# Sample orders: 4
# ======================================================
# INFO:absl:Best score of island 7 increased to -823048.3189327391
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if dynamic_cost > 0.5:
#                 priorities[city] = distance_priority * dynamic_cost + 10
#             elif distance_priority > -10:
#                 priorities[city] = distance_priority * dynamic_cost - 5
#             else:
#                 priorities[city] = distance_priority * dynamic_cost
#     return priorities
# ------------------------------------------------------
# Score        : -823048.3189327391
# Sample time  : 5.100315570831299
# Evaluate time: 3.4008378982543945
# Sample orders: 5
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v0`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             # Inverse of the distance (closer cities have higher priority)
#             distance_priority = -distances[current_city][city]
#             # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
#
#             # Additional factors
#             if distance_priority < 0:  # Prioritize cities with negative distance even more
#                 distance_priority *= 2
#             else:  # Prioritize cities with positive distance less
#                 distance_priority /= 2
#
#             if dynamic_cost > 0.5:  # Prioritize cities with higher dynamic cost even more
#                 dynamic_cost *= 3
#             else:  # Prioritize cities with lower dynamic cost less
#                 dynamic_cost /= 3
#
#             priorities[city] = distance_priority * dynamic_cost
#     return priorities
# ------------------------------------------------------
# Score        : -838152.186534627
# Sample time  : 10.135210752487183
# Evaluate time: 3.5069830417633057
# Sample orders: 6
# ======================================================
# INFO:absl:Best score of island 6 increased to -823390.9002277227
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if distance_priority < -10:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif distance_priority > -5:
#                 for i in range(num_cities):
#                     if visited[i]:
#                         priorities[city] += distances[city][i]
#             else:
#                 priorities[city] = distance_priority
#     return priorities
# ------------------------------------------------------
# Score        : -823390.9002277227
# Sample time  : 11.053990125656128
# Evaluate time: 3.556145668029785
# Sample orders: 7
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if distance_priority <= 0:
#                 priorities[city] = distance_priority * dynamic_cost * 0.5
#             else:
#                 priorities[city] = distance_priority * dynamic_cost
#     return priorities
# ------------------------------------------------------
# Score        : -838152.186534627
# Sample time  : 11.408616304397583
# Evaluate time: 3.4117274284362793
# Sample orders: 8
# ======================================================
# INFO:absl:Best score of island 2 increased to -592907.0759316741
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             # Inverse of the distance (closer cities have higher priority)
#             distance_priority = -distances[current_city][city]
#             # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
#
#             # Additional complexity: consider the number of available routes from each city
#             num_routes = np.sum(distances[city] != np.inf)
#             route_priority = np.log(num_routes + 1)  # Logarithm of number of available routes
#
#             # Additional complexity: consider the distance difference from the mean distance
#             mean_distance = np.mean(distances[city][distances[city] != np.inf])
#             distance_diff = distances[city][current_city] - mean_distance
#             if distance_diff > 0:
#                 distance_diff_priority = np.exp(-distance_diff / 10)  # Exponential decay based on distance difference
#             else:
#                 distance_diff_priority = 0
#
#             priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority
#     return priorities
# ------------------------------------------------------
# Score        : -592907.0759316741
# Sample time  : 6.510326385498047
# Evaluate time: 4.7368223667144775
# Sample orders: 9
# ======================================================
# INFO:absl:Best score of island 9 increased to -831935.8611886044
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             if city % 2 == 0:
#                 distance_priority = -distances[current_city][city] * 2
#             else:
#                 distance_priority = -distances[current_city][city]
#
#             if np.sum(distances[city]) > 100:
#                 dynamic_cost = 1 / (1 + np.sum(distances[city]) * 2)
#             else:
#                 dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             priorities[city] = distance_priority * dynamic_cost
#
#     return priorities
# ------------------------------------------------------
# Score        : -831935.8611886044
# Sample time  : 31.35464382171631
# Evaluate time: 3.6744165420532227
# Sample orders: 10
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if dynamic_cost > 0.5:
#                 priorities[city] = distance_priority * dynamic_cost + 10
#             elif dynamic_cost > 0.2 and distance_priority > -10:
#                 priorities[city] = distance_priority * dynamic_cost + 5
#             elif dynamic_cost > 0.1 and distance_priority > -20:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif dynamic_cost > 0.05 and distance_priority > -30:
#                 priorities[city] = distance_priority * dynamic_cost - 10
#             else:
#                 priorities[city] = distance_priority * dynamic_cost - 20
#     return priorities
# ------------------------------------------------------
# Score        : -838152.186534627
# Sample time  : 6.475921154022217
# Evaluate time: 3.489445209503174
# Sample orders: 11
# ======================================================
# INFO:absl:Best score of island 5 increased to -822940.2651041681
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if distance_priority <= -10:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif distance_priority <= -5:
#                 priorities[city] = distance_priority * (dynamic_cost + 0.5)
#             else:
#                 priorities[city] = distance_priority * (dynamic_cost + 1)
#     return priorities
# ------------------------------------------------------
# Score        : -822940.2651041681
# Sample time  : 9.04744553565979
# Evaluate time: 3.5236001014709473
# Sample orders: 12
# ======================================================
# INFO:absl:Best score of island 6 increased to -190709.26598233997
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if distance_priority < -10:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif distance_priority > -5:
#                 for i in range(num_cities):
#                     if visited[i]:
#                         priorities[city] += distances[city][i]
#             else:
#                 priorities[city] = distance_priority
#
#             if distances[current_city][city] > 50:
#                 priorities[city] += 10
#             elif distances[current_city][city] > 30:
#                 priorities[city] += 5
#
#             if current_city % 2 == 0:
#                 priorities[city] += 2
#
#             for i in range(num_cities):
#                 if visited[i]:
#                     priorities[city] += 0.5 * distances[i][city]
#
#     return priorities
# ------------------------------------------------------
# Score        : -190709.26598233997
# Sample time  : 17.367908000946045
# Evaluate time: 3.773331642150879
# Sample orders: 13
# ======================================================
# INFO:absl:Best score of island 1 increased to -57344.16871904707
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             # Additional heuristic: consider the number of connections from the current city
#             num_connections = np.count_nonzero(distances[current_city] != np.inf)
#
#             # Additional heuristic: prioritize cities with lower index values
#             index_priority = -city
#
#             priorities[city] = distance_priority * dynamic_cost * num_connections * index_priority
#     return priorities
# ------------------------------------------------------
# Score        : -57344.16871904707
# Sample time  : 6.492654323577881
# Evaluate time: 4.637207508087158
# Sample orders: 14
# ======================================================
# INFO:absl:Best score of island 7 increased to -679705.03445473
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             if dynamic_cost > 0.5:
#                 priorities[city] = distance_priority * dynamic_cost + 10
#             elif distance_priority > -10:
#                 priorities[city] = distance_priority * dynamic_cost - 5
#             else:
#                 priorities[city] = distance_priority * dynamic_cost
#
#             # Additional conditions based on city priority
#             if distance_priority < -20:
#                 priorities[city] -= 5
#             elif distance_priority > 20:
#                 priorities[city] += 5
#
#             if dynamic_cost > 0.7:
#                 priorities[city] += 3
#             elif dynamic_cost < 0.3:
#                 priorities[city] -= 3
#
#             if city < num_cities//2:
#                 priorities[city] *= 1.5
#             else:
#                 priorities[city] *= 0.5
#
#             priorities[city] += city % 5
#
#     return priorities
# ------------------------------------------------------
# Score        : -679705.03445473
# Sample time  : 42.67657208442688
# Evaluate time: 3.579076051712036
# Sample orders: 15
# ======================================================
# INFO:absl:Best score of island 0 increased to -742200.9475620314
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v0`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             if distances[current_city][city] == 0:
#                 distance_priority = np.inf
#             else:
#                 distance_priority = -distances[current_city][city] / np.log(distances[current_city][city])
#             dynamic_cost = 1 / (1 + np.max(distances[city]))
#             city_priority = distance_priority * dynamic_cost
#             for neighbor in range(num_cities):
#                 if distances[city][neighbor] > 0 and not visited[neighbor]:
#                     city_priority += 0.5 * distances[city][neighbor]
#             priorities[city] = city_priority
#     return priorities
# ------------------------------------------------------
# Score        : -742200.9475620314
# Sample time  : 32.506747245788574
# Evaluate time: 4.487597465515137
# Sample orders: 16
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             if city % 2 == 0:
#                 distance_priority = -distances[current_city][city] * 2
#             else:
#                 distance_priority = -distances[current_city][city]
#
#             if np.sum(distances[city]) > 100:
#                 distance_factor = np.sum(distances[city]) * 2
#             else:
#                 distance_factor = np.sum(distances[city])
#
#             dynamic_cost = 1 / (1 + distance_factor)
#
#             if current_city == 0:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif current_city % 3 == 0:
#                 priorities[city] = distance_priority * dynamic_cost + 10
#             else:
#                 priorities[city] = distance_priority * dynamic_cost - 10
#
#     return priorities
# ------------------------------------------------------
# Score        : -831935.8611886044
# Sample time  : 6.101914644241333
# Evaluate time: 3.6441855430603027
# Sample orders: 17
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if dynamic_cost > 0.5:
#                 if distance_priority > -10:
#                     priorities[city] = distance_priority * dynamic_cost + 10
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost - 5
#             else:
#                 if distance_priority > -10:
#                     priorities[city] = distance_priority * dynamic_cost - 5
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost
#
#             # Additional conditions based on city priority
#             if distance_priority < -20:
#                 priorities[city] -= 5
#             elif distance_priority > 20:
#                 priorities[city] += 5
#
#             if dynamic_cost > 0.7:
#                 priorities[city] += 3
#             elif dynamic_cost < 0.3:
#                 priorities[city] -= 3
#
#             if city < num_cities//2:
#                 priorities[city] *= 1.5
#             else:
#                 priorities[city] *= 0.5
#
#             priorities[city] += city % 5
#
#     return priorities
# ------------------------------------------------------
# Score        : -679705.03445473
# Sample time  : 14.357377529144287
# Evaluate time: 3.564177989959717
# Sample orders: 18
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if dynamic_cost > 0.5:
#                 if distance_priority > -10:
#                     priorities[city] = distance_priority * dynamic_cost + 10
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost - 5
#             else:
#                 if distance_priority > -10:
#                     priorities[city] = distance_priority * dynamic_cost - 5
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost
#
#             # Additional conditions based on city priority
#             if distance_priority < -20:
#                 priorities[city] -= 5
#             elif distance_priority > 20:
#                 priorities[city] += 5
#
#             if dynamic_cost > 0.7:
#                 priorities[city] += 3
#             elif dynamic_cost < 0.3:
#                 priorities[city] -= 3
#
#             if city < num_cities//2:
#                 priorities[city] *= 1.5
#             else:
#                 priorities[city] *= 0.5
#
#             priorities[city] += city % 5
#
#             # Additional complex conditions
#             if distances[current_city][city] < 10 and dynamic_cost > 0.6:
#                 priorities[city] += 5
#             elif distances[current_city][city] > 20 or dynamic_cost < 0.4:
#                 priorities[city] -= 2
#
#     return priorities
# ------------------------------------------------------
# Score        : -679705.03445473
# Sample time  : 15.47925329208374
# Evaluate time: 3.69191312789917
# Sample orders: 19
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             if distances[current_city][city] == 0:
#                 distance_priority = np.inf
#             else:
#                 distance_priority = -distances[current_city][city] / np.log(distances[current_city][city])
#             dynamic_cost = 1 / (1 + np.max(distances[city]))
#             city_priority = distance_priority * dynamic_cost
#             for neighbor in range(num_cities):
#                 if distances[city][neighbor] > 0 and not visited[neighbor]:
#                     city_priority += 0.5 * distances[city][neighbor]
#             if city_priority > 10:
#                 city_priority *= 1.5
#             if current_city % 2 == 0:
#                 city_priority *= 2
#             priorities[city] = city_priority
#     return priorities
# ------------------------------------------------------
# Score        : -742200.9475620314
# Sample time  : 20.053706884384155
# Evaluate time: 4.569775342941284
# Sample orders: 20
# ======================================================
# INFO:absl:Best score of island 5 increased to -588491.8941138992
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority <= -15:
#                 for i in range(city):
#                     if visited[i]:
#                         distance_priority *= 0.9
#                 priorities[city] = distance_priority * dynamic_cost
#
#             elif distance_priority <= -10:
#                 for i in range(city):
#                     if not visited[i]:
#                         distance_priority *= 1.1
#                 priorities[city] = distance_priority * (dynamic_cost + 0.5)
#
#             else:
#                 for i in range(city):
#                     if visited[i]:
#                         distance_priority *= 1.2
#                 priorities[city] = distance_priority * (dynamic_cost + 1)
#
#     return priorities
# ------------------------------------------------------
# Score        : -588491.8941138992
# Sample time  : 7.856090068817139
# Evaluate time: 3.748853921890259
# Sample orders: 21
# ======================================================
# INFO:absl:Best score of island 3 increased to -822274.0730848933
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             if distance_priority < 0:
#                 dynamic_cost = 1 / (1 + np.sum(distances[city]))
#                 if dynamic_cost > 0.5:
#                     priorities[city] = distance_priority * dynamic_cost
#                 else:
#                     priorities[city] = distance_priority
#             else:
#                 priorities[city] = distance_priority
#     return priorities
# ------------------------------------------------------
# Score        : -822274.0730848933
# Sample time  : 6.025958299636841
# Evaluate time: 3.497650146484375
# Sample orders: 22
# ======================================================
# INFO:absl:Best score of island 2 increased to -420318.68438351806
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             # Inverse of the distance (closer cities have higher priority)
#             distance_priority = -distances[current_city][city]
#             # Additional heuristic: dynamic cost based on some external condition or iteration dependent factor
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))  # Example: inverse of sum of distances from this city
#
#             # Additional complexity: consider the number of available routes from each city
#             num_routes = np.sum(distances[city] != np.inf)
#             route_priority = np.log(num_routes + 1)  # Logarithm of number of available routes
#
#             # Additional complexity: consider the distance difference from the mean distance
#             mean_distance = np.mean(distances[city][distances[city] != np.inf])
#             distance_diff = distances[city][current_city] - mean_distance
#             if distance_diff > 0:
#                 distance_diff_priority = np.exp(-distance_diff / 10)  # Exponential decay based on distance difference
#             else:
#                 distance_diff_priority = 0
#
#             # Additional complexity: consider the number of cities within a certain distance threshold
#             num_cities_within_threshold = np.sum(distances[current_city] <= 100)
#             if num_cities_within_threshold > 5:
#                 distance_threshold_priority = np.log(num_cities_within_threshold + 1)
#             else:
#                 distance_threshold_priority = 0
#
#             priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority * distance_threshold_priority
#     return priorities
# ------------------------------------------------------
# Score        : -420318.68438351806
# Sample time  : 8.25204086303711
# Evaluate time: 4.907715797424316
# Sample orders: 23
# ======================================================
# INFO:absl:Best score of island 3 increased to -132340.99874375036
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             if distance_priority < 0:
#                 dynamic_cost = 1 / (1 + np.sum(distances[city]))
#                 if dynamic_cost > 0.5:
#                     priorities[city] = distance_priority * dynamic_cost
#                 else:
#                     max_distance = np.max(distances)
#                     priorities[city] = distance_priority + max_distance
#             else:
#                 min_distance = np.min(distances)
#                 priorities[city] = distance_priority - min_distance
#     return priorities
# ------------------------------------------------------
# Score        : -132340.99874375036
# Sample time  : 6.20344614982605
# Evaluate time: 36.677653074264526
# Sample orders: 24
# ======================================================
# INFO:absl:Best score of island 2 increased to -38452.166877705764
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             num_routes = np.sum(distances[city] != np.inf)
#             route_priority = np.log(num_routes + 1)
#
#             mean_distance = np.mean(distances[city][distances[city] != np.inf])
#             distance_diff = distances[city][current_city] - mean_distance
#             if distance_diff > 0:
#                 distance_diff_priority = np.exp(-distance_diff / 10)
#             else:
#                 distance_diff_priority = 0
#
#             num_cities_within_threshold = np.sum(distances[current_city] <= 100)
#             if num_cities_within_threshold > 5:
#                 distance_threshold_priority = np.log(num_cities_within_threshold + 1)
#             else:
#                 distance_threshold_priority = 0
#
#             if distance_priority > 0:
#                 priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority * distance_threshold_priority
#             elif distance_priority < 0:
#                 priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority / distance_threshold_priority
#     return priorities
# ------------------------------------------------------
# Score        : -38452.166877705764
# Sample time  : 51.57739973068237
# Evaluate time: 4.187482595443726
# Sample orders: 25
# ======================================================
# INFO:absl:Best score of island 6 increased to -188216.9233665264
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority < -10:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif distance_priority > -5:
#                 for i in range(num_cities):
#                     if visited[i]:
#                         priorities[city] += distances[city][i]
#             else:
#                 priorities[city] = distance_priority
#
#             if distances[current_city][city] > 50:
#                 priorities[city] += 10
#             elif distances[current_city][city] > 30:
#                 priorities[city] += 5
#
#             if current_city % 2 == 0:
#                 priorities[city] += 2
#
#             for i in range(num_cities):
#                 if visited[i]:
#                     priorities[city] += 0.5 * distances[i][city]
#
#             if current_city == 0:
#                 priorities[city] += 1
#
#             if distance_priority < -15:
#                 for i in range(num_cities):
#                     if i != city:
#                         priorities[city] += distances[i][city] if visited[i] else 0
#
#             if current_city > num_cities / 2:
#                 priorities[city] += current_city
#
#             if city % 5 == 0:
#                 priorities[city] += 3
#
#             if visited[current_city]:
#                 priorities[city] += 4
#
#             priorities[city] += np.mean(distances[city])
#
#     return priorities
# ------------------------------------------------------
# Score        : -188216.9233665264
# Sample time  : 16.718804597854614
# Evaluate time: 4.613699674606323
# Sample orders: 26
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             num_connections = np.count_nonzero(distances[current_city] != np.inf)
#
#             index_priority = -city
#
#             # Additional heuristic: consider the distance to previous city
#             prev_city_distance = distances[city][current_city]
#
#             # Additional heuristic: consider the number of unvisited neighboring cities
#             unvisited_neighbours = 0
#             for neighbour in range(num_cities):
#                 if not visited[neighbour] and distances[city][neighbour] != np.inf:
#                     unvisited_neighbours += 1
#
#             # Additional heuristic: consider the nearest unvisited city
#             nearest_unvisited = np.min(distances[city][~visited])
#
#             priorities[city] = distance_priority * dynamic_cost * num_connections * index_priority * prev_city_distance * unvisited_neighbours * nearest_unvisited
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 29.91301417350769
# Evaluate time: 3.4990949630737305
# Sample orders: 27
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             num_connections = np.count_nonzero(distances[current_city] != np.inf)
#             index_priority = -city
#
#             if current_city == city:
#                 priorities[city] = 0
#             elif num_connections > 3:
#                 priorities[city] = distance_priority * dynamic_cost * num_connections * index_priority
#             else:
#                 priorities[city] = distance_priority * dynamic_cost / num_connections * index_priority
#
#     return priorities
# ------------------------------------------------------
# Score        : -57344.16871904707
# Sample time  : 6.413745164871216
# Evaluate time: 4.748976707458496
# Sample orders: 28
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             num_neighbors = np.count_nonzero(distances[city])
#             if num_neighbors == 0:
#                 distance_priority *= 0.5
#             else:
#                 for neighbor in range(num_cities):
#                     if distances[city][neighbor] != 0:
#                         priorities[city] += distances[city][neighbor] / num_neighbors
#
#             if city % 2 == 0:
#                 priorities[city] *= 1.2
#
#             if distances[current_city][city] > np.mean(distances[current_city]) and distances[current_city][city] > np.mean(distances[:, city]):
#                 priorities[city] += 1
#
#             if city == np.argmax(distances[current_city]):
#                 priorities[city] += 5
#
#             if np.any(distances[current_city] > 100) and distances[current_city][city] > 100:
#                 priorities[city] += 2
#
#             if np.all(distances[current_city] > 10) or np.all(distances[:, city] > 10):
#                 priorities[city] += 3
#
#     return priorities
# ------------------------------------------------------
# Score        : 0.0
# Sample time  : 8.331906795501709
# Evaluate time: 7.2758002281188965
# Sample orders: 29
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             num_connections = np.count_nonzero(distances[current_city] != np.inf)
#             index_priority = -city
#
#             if current_city == city:
#                 priorities[city] = 0
#             elif num_connections > 3:
#                 if distance_priority > 0:
#                     priorities[city] = distance_priority * dynamic_cost * num_connections * index_priority
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost * num_connections
#             else:
#                 if distance_priority > 0:
#                     priorities[city] = distance_priority * dynamic_cost / num_connections * index_priority
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost / num_connections
#
#     return priorities
# ------------------------------------------------------
# Score        : -838152.186534627
# Sample time  : 7.680713653564453
# Evaluate time: 4.737783432006836
# Sample orders: 30
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             if distance_priority < 0:
#                 dynamic_cost = 1 / (1 + np.sum(distances[city]))
#                 if dynamic_cost > 0.5:
#                     priorities[city] = distance_priority * dynamic_cost
#                 else:
#                     max_distance = np.max(distances)
#                     priorities[city] = distance_priority + max_distance
#             else:
#                 min_distance = np.min(distances)
#                 priorities[city] = distance_priority - min_distance
#         else:
#             priorities[city] = np.inf
#     return priorities
# ------------------------------------------------------
# Score        : -132340.99874375036
# Sample time  : 36.693578481674194
# Evaluate time: 36.631356954574585
# Sample orders: 31
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
# ...
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             num_neighbors = np.count_nonzero(distances[city])
#             if num_neighbors == 0:
#                 distance_priority *= 0.5
#             else:
#                 for neighbor in range(num_cities):
#                     if distances[city][neighbor] != 0:
#                         priorities[city] += distances[city][neighbor] / num_neighbors
#
#             if city % 2 == 0:
#                 priorities[city] *= 1.2
#
#             if distances[current_city][city] > np.mean(distances[current_city]) and distances[current_city][city] > np.mean(distances[:, city]):
#                 priorities[city] += 1
#
#             if city == np.argmax(distances[current_city]):
#                 priorities[city] += 5
#
#             if current_city % 2 == 0:
#                 for i in range(num_cities):
#                     if distances[current_city][i] > np.mean(distances[current_city]) and distances[current_city][i] > np.mean(distances[:, current_city]):
#                         priorities[i] += 2
#
#             if current_city < city:
#                 priorities[city] -= 0.5
#
#             if city % (current_city + 1) == 0:
#                 priorities[city] += 0.5
#
#     return priorities
# ------------------------------------------------------
# Score        : 0.0
# Sample time  : 9.520009756088257
# Evaluate time: 42.80631494522095
# Sample orders: 73
# ======================================================
# INFO:absl:Best score of island 1 increased to 0.0
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     max_distance = np.max(distances)
#     min_distance = np.min(distances)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             distance = distances[current_city][city]
#
#             if distance == np.inf:
#                 distance_priority = max_distance
#             else:
#                 distance_priority = -distance
#
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             num_connections = np.count_nonzero(distances[current_city] != np.inf)
#
#             index_priority = -city
#
#             if current_city == city:
#                 priorities[city] = 0
#             elif num_connections < 2:
#                 priorities[city] = distance_priority * dynamic_cost * num_connections * index_priority
#             else:
#                 for i in range(num_connections):
#                     if i % 2 == 0:
#                         priorities[city] += distance_priority * dynamic_cost / (i + 1) * index_priority
#                     else:
#                         priorities[city] -= distance_priority * dynamic_cost / (i + 1) * index_priority
#
#     return priorities
# ------------------------------------------------------
# Score        : 0.0
# Sample time  : 13.806682109832764
# Evaluate time: 7.144632577896118
# Sample orders: 74
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority < -10:
#                 priorities[city] = distance_priority * dynamic_cost
#             elif distance_priority > -5:
#                 for i in range(num_cities):
#                     if visited[i]:
#                         priorities[city] += distances[city][i]
#             else:
#                 priorities[city] = distance_priority
#
#             if distances[current_city][city] > 50:
#                 priorities[city] += 10
#             elif distances[current_city][city] > 30:
#                 priorities[city] += 5
#
#             if current_city % 2 == 0:
#                 priorities[city] += 2
#
#             for i in range(num_cities):
#                 if visited[i]:
#                     priorities[city] += 0.5 * distances[i][city]
#
#             if current_city == 0:
#                 priorities[city] += 1
#
#             if distance_priority < -15:
#                 for i in range(num_cities):
#                     if i != city:
#                         priorities[city] += distances[i][city] if visited[i] else 0
#
#             if current_city > num_cities / 2:
#                 priorities[city] += current_city
#
#             if city % 5 == 0:
#                 priorities[city] += 3
#
#             if visited[current_city]:
#                 priorities[city] += 4
#
#             priorities[city] += np.mean(distances[city])
#
#             # New factors added to the priority calculation
#             if visited[(city + 1) % num_cities]:
#                 priorities[city] += 2
#
#             if current_city < num_cities / 3:
#                 priorities[city] += 3
#
#             for i in range(num_cities):
#                 if visited[i]:
#                     priorities[city] += distances[city][i] / np.sum(distances[i])
#
#             # New conditions and factors added
#             if current_city % 3 == 0 and visited[city]:
#                 priorities[city] += np.max(distances[city])
# ------------------------------------------------------
# Score        : None
# Sample time  : 32.25861430168152
# Evaluate time: 5.15727686882019
# Sample orders: 75
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#             num_routes = np.sum(distances[city] != np.inf)
#             route_priority = np.log(num_routes + 1)
#
#             mean_distance = np.mean(distances[city][distances[city] != np.inf])
#             distance_diff = distances[city][current_city] - mean_distance
#             if distance_diff > 0:
#                 distance_diff_priority = np.exp(-distance_diff / 10)
#             else:
#                 distance_diff_priority = 0
#
#             num_cities_within_threshold = np.sum(distances[current_city] <= 100)
#             if num_cities_within_threshold > 5:
#                 distance_threshold_priority = np.log(num_cities_within_threshold + 1)
#             else:
#                 distance_threshold_priority = 0
#
#             if distance_priority > 0:
#                 priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority * distance_threshold_priority
#             elif distance_priority < 0:
#                 priorities[city] = distance_priority * dynamic_cost * route_priority * distance_diff_priority / distance_threshold_priority
#
#             if city % 2 == 0:
#                 priorities[city] += 10
#
#             for i in range(1, city+1):
#                 priorities[city] += i
#
#             if current_city == 0 and city == num_cities-1:
#                 priorities[city] *= 2
#
#             if city == current_city:
#                 priorities[city] *= 1.5
#             elif city > current_city:
#                 priorities[city] *= 1.2
#             else:
#                 priorities[city] *= 0.8
#
#     return priorities
# ------------------------------------------------------
# Score        : -2915.0153434771155
# Sample time  : 44.31043076515198
# Evaluate time: 4.607548236846924
# Sample orders: 76
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority <= -15:
#                 for i in range(city):
#                     if visited[i]:
#                         distance_priority *= 0.9
#                     else:
#                         distance_priority *= 1.2
#                 priorities[city] = distance_priority * dynamic_cost
#
#             elif distance_priority <= -10:
#                 for i in range(city):
#                     if visited[i]:
#                         distance_priority *= 0.8
#                     else:
#                         distance_priority *= 1.3
#                 priorities[city] = distance_priority * (dynamic_cost + 0.5)
#
#             else:
#                 for i in range(city):
#                     if visited[i]:
#                         distance_priority *= 1.2
#                     else:
#                         distance_priority *= 0.9
#                 priorities[city] = distance_priority * (dynamic_cost + 1)
#
#                 if current_city == city:
#                     priorities[city] *= 2
#
#     return priorities
# ------------------------------------------------------
# Score        : -542403.5792991576
# Sample time  : 11.719985485076904
# Evaluate time: 3.853849411010742
# Sample orders: 77
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority > -10:
#                 priorities[city] = distance_priority * dynamic_cost - 5
#             else:
#                 priorities[city] = distance_priority * dynamic_cost
#
#             if distance_priority < -20:
#                 priorities[city] -= 5
#             elif distance_priority > 20:
#                 priorities[city] += 5
#
#             if dynamic_cost > 0.7:
#                 priorities[city] += 3
#             elif dynamic_cost < 0.3:
#                 priorities[city] -= 3
#
#             if city < num_cities//2:
#                 priorities[city] *= 1.5
#             else:
#                 priorities[city] *= 0.5
#
#             priorities[city] += city % 5
#
#             if distances[current_city][city] < 10 and dynamic_cost > 0.6:
#                 priorities[city] += 5
#             elif distances[current_city][city] > 20 or dynamic_cost < 0.4:
#                 priorities[city] -= 2
#
#     return priorities
# ------------------------------------------------------
# Score        : -679705.03445473
# Sample time  : 7.437778949737549
# Evaluate time: 3.9149091243743896
# Sample orders: 78
# ======================================================
# INFO:absl:Best score of island 7 increased to -677252.7873284416
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     """Improved version of `priority_v1`."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if dynamic_cost > 0.6:
#                 if distance_priority > -15:
#                     priorities[city] = distance_priority * dynamic_cost + 10
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost + 5
#             else:
#                 if distance_priority > -15:
#                     priorities[city] = distance_priority * dynamic_cost + 5
#                 else:
#                     priorities[city] = distance_priority * dynamic_cost
#
#             # Additional conditions based on city priority
#             if distance_priority < -25:
#                 priorities[city] -= 5
#             elif distance_priority > 25:
#                 priorities[city] += 10
#
#             if dynamic_cost > 0.8:
#                 priorities[city] += 5
#             elif dynamic_cost < 0.2:
#                 priorities[city] -= 5
#
#             if city < num_cities//2:
#                 priorities[city] *= 1.7
#             else:
#                 priorities[city] *= 0.7
#
#             priorities[city] += city % 3
#
#             if distances[current_city][city] < 5 and dynamic_cost > 0.7:
#                 priorities[city] += 10
#             elif distances[current_city][city] > 15 or dynamic_cost < 0.3:
#                 priorities[city] -= 5
#
#     return priorities
# ------------------------------------------------------
# Score        : -677252.7873284416
# Sample time  : 7.935357093811035
# Evaluate time: 3.8348989486694336
# Sample orders: 79
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(current_city, distances, visited):
#     """Calculate complex priorities for each city from the current city based on negative distance and other factors."""
#     num_cities = len(distances)
#     priorities = np.full(num_cities, np.inf)
#
#     for city in range(num_cities):
#         if not visited[city]:
#             distance_priority = -distances[current_city][city]
#             dynamic_cost = 1 / (1 + np.sum(distances[city]))
#
#             if distance_priority <= -20:
#                 priority = distance_priority * dynamic_cost
#
#                 if current_city == city:
#                     priority *= 1.5
#
#                 priorities[city] = priority
#
#             elif distance_priority <= -10:
#                 priority = distance_priority * (dynamic_cost + 1)
#
#                 for i in range(city):
#                     if visited[i] == True:
#                         priority *= 0.8
#                     else:
#                         priority *= 1.2
#
#                 priorities[city] = priority
#
#             else:
#                 priority = distance_priority * (dynamic_cost + 0.5)
#
#                 for i in range(city):
#                     if visited[i] == True:
#                         priority *= 0.7
#                     else:
#                         priority *= 1.3
#
#                 priorities[city] = priority
#
#     return priorities
# ------------------------------------------------------
# Score        : -815439.5048634046
# Sample time  : 7.829643487930298
# Evaluate time: 3.7344539165496826
# Sample orders: 80
# ======================================================
